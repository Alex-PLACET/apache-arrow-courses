# %% [markdown]
# # Why Apache Arrow?
#
# > **Level:** Beginner
# > **Spec:** [Arrow Columnar Format Introduction](https://arrow.apache.org/docs/format/Columnar.html)
# > **PyArrow docs:** [Getting Started](https://arrow.apache.org/docs/python/getstarted.html)
#
# ## What you will learn
#
# 1. Why columnar storage outperforms row storage for analytics
# 2. Arrow's core guarantees: shared memory, zero-copy, ABI stability
# 3. Vocabulary: `Array`, `Buffer`, `Schema`, `RecordBatch`, `Table`

# %%
import time
import pyarrow as pa
import pyarrow.compute as pc
import numpy as np

# %% [markdown]
# ---
# ## 1. Row vs Columnar Storage
#
# > **Further reading:** [Why columnar?](https://arrow.apache.org/docs/format/Columnar.html#physical-memory-layout)
#
# Imagine a table with 1 million student records: `(name, score, grade)`.
# An analytics query that computes **sum(score)** needs only the `score` column.
#
# | Storage | Data read | Cache behaviour |
# |---------|-----------|----------------|
# | Row (CSV / SQL heap) | Entire row (name + score + grade) | Poor: many cache misses |
# | Columnar (Arrow) | Score buffer only | Excellent: sequential scan |

# %%
N = 1_000_000
rng = np.random.default_rng(42)
scores_np = rng.integers(0, 100, size=N)

# Row-oriented: list of dicts (Python objects, no contiguous memory)
rows = [{"name": f"student_{i}", "score": int(scores_np[i]), "grade": "A"} for i in range(N)]

# Column-oriented options
scores_list = scores_np.tolist()          # Python list
arrow_scores = pa.array(scores_np, type=pa.int32())  # Arrow array

# Benchmark: sum(score)
t0 = time.perf_counter()
row_sum = sum(r["score"] for r in rows)
t_rows = (time.perf_counter() - t0) * 1000

t0 = time.perf_counter()
list_sum = sum(scores_list)
t_list = (time.perf_counter() - t0) * 1000

t0 = time.perf_counter()
arrow_sum = pc.sum(arrow_scores)
t_arrow = (time.perf_counter() - t0) * 1000

print(f"Sum (all agree): {row_sum == list_sum == arrow_sum.as_py()}")
print(f"\nRow iteration  : {t_rows:7.1f} ms")
print(f"Python list    : {t_list:7.1f} ms")
print(f"Arrow compute  : {t_arrow:7.1f} ms")
print(f"\nArrow speedup vs rows : {t_rows/t_arrow:.0f}x")
# Out:
# Sum (all agree): True
#
# Row iteration  :    29.1 ms
# Python list    :     4.8 ms
# Arrow compute  :     0.4 ms
#
# Arrow speedup vs rows : 72x

# %% [markdown]
# ---
# ## 2. Arrow's Four Guarantees
#
# > **Spec:** [Goals](https://arrow.apache.org/docs/format/Columnar.html#goals)
#
# | Guarantee | Meaning |
# |-----------|---------|
# | **Contiguous buffers** | Each column is a flat byte buffer: CPU-friendly, SIMD-ready |
# | **Shared memory** | Multiple processes can map the same buffer (no copy) |
# | **Language-agnostic** | Same binary layout in Python, Rust, Java, C++, Go, R … |
# | **Null support** | A validity *bitmap* encodes missing values without NaN hacks |

# %%
# Arrow vocabulary:

# Buffer: raw bytes
buf = pa.py_buffer(b"\x01\x00\x03\x00\x04\x00")  # 3 x int16
print("Buffer bytes:", buf.to_pybytes().hex())

# Array: typed view of buffers
arr = pa.array([1, None, 3, 4], type=pa.int32())
print("\nArray:", arr)
print("Type:", arr.type)
print("Null count:", arr.null_count)
print("Buffer count:", len(arr.buffers()))

# Schema: named fields with types
schema = pa.schema([
    pa.field("name",  pa.utf8()),
    pa.field("score", pa.int32()),
    pa.field("grade", pa.utf8()),
])
print("\nSchema:", schema)

# RecordBatch: schema + equal-length column arrays
batch = pa.record_batch({
    "name":  ["Alice", "Bob", "Carol"],
    "score": [95, 82, 91],
    "grade": ["A", "B", "A"],
}, schema=schema)
print("\nRecordBatch:\n", batch.to_pandas())

# Table: collection of RecordBatches (possibly chunked)
table = pa.table({"score": pa.chunked_array([pa.array([95, 82]), pa.array([91, 77])])})
print("\nTable num_chunks:", table.column(0).num_chunks)
# Out:
# Buffer bytes: 010003000400
#
# Array: [
#   1,
#   null,
#   3,
#   4
# ]
# Type: int32
# Null count: 1
# Buffer count: 2
#
# Schema: name: string
# score: int32
# grade: string
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 30
#      23 # RecordBatch: schema + equal-length column arrays
#      24 batch = pa.record_batch({
#      25     "name":  ["Alice", "Bob", "Carol"],
#      26     "score": [95, 82, 91],
#      27     "grade": ["A", "B", "A"],
#      28 }, schema=schema)
# ---> 30 itables.show(batch)
#      31 # Table: collection of RecordBatches (possibly chunked)
#      32 table = pa.table({"score": pa.chunked_array([pa.array([95, 82]), pa.array([91, 77])])})
#
# File ~/Dev/apache-arrow-courses/.pixi/envs/default/lib/python3.14/site-packages/itables/javascript.py:1086, in show(df, caption, **kwargs)
#    1083 """Render the given dataframe as an interactive datatable"""
#    1084 from IPython.display import HTML, display
# -> 1086 display(HTML(to_html_datatable(df, caption, **kwargs)))
#
# File ~/Dev/apache-arrow-courses/.pixi/envs/default/lib/python3.14/site-packages/itables/javascript.py:408, in to_html_datatable(df, caption, **kwargs)
#     401 """
#     402 Return the HTML representation of the given
#     403 dataframe as an interactive datatable
#     404 """
#     405 kwargs["table_id"] = table_id = check_table_id(
#     406     kwargs.pop("table_id", None), kwargs, df=df
#     407 )
# --> 408 dt_args = get_itable_arguments(df, caption, **kwargs)
#     409 dt_url = dt_args.pop("dt_url")
#     410 connected = dt_args.pop("connected")
#
# File ~/Dev/apache-arrow-courses/.pixi/envs/default/lib/python3.14/site-packages/itables/javascript.py:595, in get_itable_arguments(df, caption, app_mode, **kwargs)
#     591         raise TypeError(
#     592             "Narwhals is required to render DataFrames other than Pandas or Polars"
#     593         ) from e
#     594     else:
# --> 595         df = nw.from_native(df, eager_only=True, allow_series=True)
#     597 warn_on_unexpected_types = kwargs.pop("warn_on_unexpected_types", False)
#     598 allow_html = kwargs.pop("allow_html")
#
# File ~/Dev/apache-arrow-courses/.pixi/envs/default/lib/python3.14/site-packages/narwhals/translate.py:210, in from_native(native_object, pass_through, eager_only, series_only, allow_series)
#     167 def from_native(
#     168     native_object: IntoLazyFrameT
#     169     | IntoDataFrameT
#    (...)    178     allow_series: bool | None = None,
#     179 ) -> LazyFrame[IntoLazyFrameT] | DataFrame[IntoDataFrameT] | Series[IntoSeriesT] | T:
#     180     """Convert `native_object` to Narwhals Dataframe, Lazyframe, or Series.
#     181
#     182     Arguments:
#    (...)    208             on which combination of parameters was passed.
#     209     """
# --> 210     return _from_native_impl(  # type: ignore[no-any-return]
#     211         native_object,
#     212         pass_through=pass_through,
#     213         eager_only=eager_only,
#     214         eager_or_interchange_only=False,
#     215         series_only=series_only,
#     216         allow_series=allow_series,
#     217         version=Version.MAIN,
#     218     )
#
# File ~/Dev/apache-arrow-courses/.pixi/envs/default/lib/python3.14/site-packages/narwhals/translate.py:467, in _from_native_impl(native_object, pass_through, eager_only, eager_or_interchange_only, series_only, allow_series, version)
#     465     if hint := plugins._show_suggestions(type(native_object)):  # pragma: no cover
#     466         msg += "\n\n" + hint
# --> 467     raise TypeError(msg)
#     468 return native_object
#
# TypeError: Unsupported dataframe type, got: <class 'pyarrow.lib.RecordBatch'>

# %% [markdown]
# ---
# ## Summary
#
# - Columnar layout enables sequential memory access → cache-friendly → fast SIMD aggregation
# - Arrow arrays are backed by contiguous `Buffer` objects with a validity bitmap for nulls
# - `RecordBatch` = schema + equal-length columns; `Table` = chunked collection of batches
# - Arrow unifies in-memory representation across languages, one buffer, many readers
#
# **Next ⏭️** [Inspect the raw bytes of Arrow buffers](02_arrays_buffers_nulls.ipynb)
